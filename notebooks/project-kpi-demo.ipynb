# %% [markdown]
# # Project Dashboard Analytics - KPIs
#
# Exemplo de calculo de indicadores para uma carteira sintetica de projetos.

# %%
import pandas as pd
df = pd.read_csv('../data/projetos_exemplo.csv')
df['desvio_custo_kbrl'] = df['custo_real_kbrl'] - df['custo_planejado_kbrl']
df['indice_beneficio_custo'] = df['beneficio_estimado_kbrl'] / df['custo_planejado_kbrl']
df[['projeto','status','progresso_pct','risco','desvio_custo_kbrl','indice_beneficio_custo']]
